# %%
# !pip install stable-baselines3==2.1.0 gymnasium[atari] ale-py imageio matplotlib
# Out:
# Requirement already satisfied: stable-baselines3==2.1.0 in /usr/local/lib/python3.10/dist-packages (2.1.0)
# Collecting ale-py
#   Downloading ale_py-0.10.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.2 kB)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.36.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.10/dist-packages (0.29.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.1.0) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.1.0) (2.5.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.1.0) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.1.0) (2.2.3)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (0.0.4)
# Collecting shimmy<1.0,>=0.1.0 (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[atari])
#   Downloading Shimmy-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable-baselines3==2.1.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable-baselines3==2.1.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable-baselines3==2.1.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable-baselines3==2.1.0) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable-baselines3==2.1.0) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable-baselines3==2.1.0) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting ale-py
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py) (5.13.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3==2.1.0) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3==2.1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3==2.1.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3==2.1.0) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3==2.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3==2.1.0) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3==2.1.0) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3==2.1.0) (2025.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3==2.1.0) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.20->stable-baselines3==2.1.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.20->stable-baselines3==2.1.0) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.20->stable-baselines3==2.1.0) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.20->stable-baselines3==2.1.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.20->stable-baselines3==2.1.0) (2024.2.0)
# Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 21.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: shimmy, ale-py
#   Attempting uninstall: shimmy
#     Found existing installation: Shimmy 1.3.0
#     Uninstalling Shimmy-1.3.0:
#       Successfully uninstalled Shimmy-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle-environments 1.16.11 requires shimmy>=1.2.1, but you have shimmy 0.2.1 which is incompatible.
# Successfully installed ale-py-0.8.1 shimmy-0.2.1

# %%
# !pip install gymnasium[accept-rom-license]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Requirement already satisfied: gymnasium[accept-rom-license] in /usr/local/lib/python3.10/dist-packages (0.29.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (0.0.4)
# Collecting autorom~=0.4.2 (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license])
#   Downloading AutoROM-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (4.67.1)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 8.0 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium[accept-rom-license]) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium[accept-rom-license]) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium[accept-rom-license]) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium[accept-rom-license]) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium[accept-rom-license]) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium[accept-rom-license]) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.0->gymnasium[accept-rom-license]) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.0->gymnasium[accept-rom-license]) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.0->gymnasium[accept-rom-license]) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.21.0->gymnasium[accept-rom-license]) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license]) (2025.1.31)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.21.0->gymnasium[accept-rom-license]) (2024.2.0)
# Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=autorom_accept_rom_license-0.6.1-py3-none-any.whl size=446710 sha256=844423cba1c7718b876497ee789db7b05bd2748cc480dbf88ebdc8aa78b3df2c
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.4.2

# %%
import gymnasium as gym
from stable_baselines3 import DQN
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.logger import configure
from stable_baselines3.common.vec_env import VecFrameStack

# Use the Breakout environment (NoFrameskip version for Atari pre-processing)
env_id = "BreakoutNoFrameskip-v4"

# Create the environment with a single instance and a fixed seed for reproducibility.
env = make_atari_env(env_id, n_envs=1, seed=42)

# Stack 4 consecutive frames (standard for Atari agents)
env = VecFrameStack(env, n_stack=4)

# Use the CNN policy 
policy = "CnnPolicy"

model = DQN(
    policy,
    env,
    learning_rate=1e-4,
    gamma=0.99,
    batch_size=32,
    buffer_size=100000,
    exploration_initial_eps=1.0,
    exploration_final_eps=0.01,
    exploration_fraction=0.1,
    target_update_interval=1000,
    train_freq=4,
    gradient_steps=1,
    verbose=1,
    tensorboard_log="./dqn_tensorboard/"
)

# Configure logger to output to stdout, CSV, and tensorboard 
logger = configure("./dqn_logs/", ["stdout", "csv", "tensorboard"])
model.set_logger(logger)

# Callback to save the model at every 10,000 steps
checkpoint_callback = CheckpointCallback(save_freq=10000, save_path="./checkpoints/")

# training for 1,000,000 timesteps now
model.learn(
    total_timesteps=1_000_000,
    callback=checkpoint_callback,
    tb_log_name="dqn_breakout"
)

# Save the final model
model.save("dqn_breakout_model")

env.close()
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./dqn_logs/
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 263      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 92       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 524      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 451      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 327      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 819      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 501      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 515      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 851      |
# |    ep_rew_mean      | 1.67     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 510      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 607      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 798      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 521      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 725      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 798      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 547      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 988      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 877      |
# |    ep_rew_mean      | 2        |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 536      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1108     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 838      |
# |    ep_rew_mean      | 1.83     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 539      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 792      |
# |    ep_rew_mean      | 1.57     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 545      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1318     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 775      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 549      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1410     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 775      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 559      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1575     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 779      |
# |    ep_rew_mean      | 1.56     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 560      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1665     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 753      |
# |    ep_rew_mean      | 1.4      |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 562      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 733      |
# |    ep_rew_mean      | 1.27     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 563      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1847     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 715      |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 565      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 715      |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 568      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2029     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 700      |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 570      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 688      |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 572      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 690      |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 573      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2350     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 704      |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 578      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2539     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 704      |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 578      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2627     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 692      |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 576      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2717     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 682      |
# |    ep_rew_mean      | 0.944    |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 576      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2835     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 679      |
# |    ep_rew_mean      | 0.947    |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 577      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2925     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 700      |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 582      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 3159     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 700      |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 584      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 3249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 691      |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 584      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 3386     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 692      |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 582      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 3478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 685      |
# |    ep_rew_mean      | 0.957    |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 584      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 3668     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 712      |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 586      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 3857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 712      |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 587      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 3949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 704      |
# |    ep_rew_mean      | 1.04     |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 589      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 4114     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 708      |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 590      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 4281     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 712      |
# |    ep_rew_mean      | 1.11     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 589      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 4371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 711      |
# |    ep_rew_mean      | 1.11     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 589      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 4507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 711      |
# |    ep_rew_mean      | 1.11     |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 593      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 4772     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 728      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 593      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 4862     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 728      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 594      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 5000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 724      |
# |    ep_rew_mean      | 1.19     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 594      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 5118     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 718      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 594      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 5208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 718      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 596      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 5348     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 717      |
# |    ep_rew_mean      | 1.15     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 596      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 5436     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 712      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 596      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 5577     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 713      |
# |    ep_rew_mean      | 1.11     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 596      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 5669     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 708      |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 596      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 5761     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 708      |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 597      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 5851     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 702      |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 596      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 5943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 703      |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 599      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 6204     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 716      |
# |    ep_rew_mean      | 1.13     |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 599      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 6343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 715      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 600      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 6476     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 715      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 601      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 6641     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 718      |
# |    ep_rew_mean      | 1.15     |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 601      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 6729     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 713      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 601      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 6819     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 708      |
# |    ep_rew_mean      | 1.09     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 600      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 6911     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 704      |
# |    ep_rew_mean      | 1.07     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 600      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 7001     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 704      |
# |    ep_rew_mean      | 1.07     |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 601      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 7121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 707      |
# |    ep_rew_mean      | 1.09     |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 601      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 7260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 703      |
# |    ep_rew_mean      | 1.07     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 602      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 7378     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 702      |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 602      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 7500     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 704      |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 602      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 7634     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 704      |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 604      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 7845     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 714      |
# |    ep_rew_mean      | 1.14     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 605      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 8061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 716      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 605      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 8149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 722      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 606      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 8362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 724      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 606      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 8529     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 724      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 606      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 8621     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 721      |
# |    ep_rew_mean      | 1.19     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 607      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 8806     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 727      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 607      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 8946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 725      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 607      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 9063     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 721      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 607      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 9153     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 721      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 607      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 9245     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 718      |
# |    ep_rew_mean      | 1.18     |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 607      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 9337     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 715      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 607      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 9425     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 711      |
# |    ep_rew_mean      | 1.14     |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 607      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 9513     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 708      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 607      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 9603     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 708      |
# |    ep_rew_mean      | 1.12     |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 608      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 9788     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 711      |
# |    ep_rew_mean      | 1.13     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 608      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 9878     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 708      |
# |    ep_rew_mean      | 1.11     |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 608      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 9970     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 710      |
# |    ep_rew_mean      | 1.13     |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 606      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 10133    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 713      |
# |    ep_rew_mean      | 1.14     |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 606      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 10321    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 713      |
# |    ep_rew_mean      | 1.14     |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 606      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 10586    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 720      |
# |    ep_rew_mean      | 1.18     |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 606      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 10725    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 726      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 607      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 10910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 723      |
# |    ep_rew_mean      | 1.19     |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 606      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 11000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 723      |
# |    ep_rew_mean      | 1.19     |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 606      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 11135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 723      |
# |    ep_rew_mean      | 1.19     |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 607      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 11322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 728      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 607      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 11508    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 728      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 607      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 11600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 725      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 606      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 11690    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 723      |
# |    ep_rew_mean      | 1.18     |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 606      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 11780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 723      |
# |    ep_rew_mean      | 1.18     |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 606      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 11918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 723      |
# |    ep_rew_mean      | 1.18     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 606      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 12008    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 720      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 605      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 12100    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 720      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 605      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 12240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 725      |
# |    ep_rew_mean      | 1.18     |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 606      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 12474    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 725      |
# |    ep_rew_mean      | 1.18     |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 606      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 12608    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 725      |
# |    ep_rew_mean      | 1.18     |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 606      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 12698    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 722      |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 606      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 12786    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 723      |
# |    ep_rew_mean      | 1.18     |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 606      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 12949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 723      |
# |    ep_rew_mean      | 1.18     |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 606      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 13085    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 723      |
# |    ep_rew_mean      | 1.18     |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 606      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 13175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 720      |
# |    ep_rew_mean      | 1.16     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 606      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 13340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 722      |
# |    ep_rew_mean      | 1.17     |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 606      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 13505    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 724      |
# |    ep_rew_mean      | 1.19     |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 606      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 13627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 725      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 606      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 13792    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 725      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 607      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 13928    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 727      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 607      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 14140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 728      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 607      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 14230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 728      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 607      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 14370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 726      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 607      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 14462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 726      |
# |    ep_rew_mean      | 1.2      |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 608      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 14626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 727      |
# |    ep_rew_mean      | 1.21     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 608      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 14838    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 732      |
# |    ep_rew_mean      | 1.24     |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 608      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 14975    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 734      |
# |    ep_rew_mean      | 1.26     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 608      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 15168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 732      |
# |    ep_rew_mean      | 1.25     |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 608      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 15260    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 732      |
# |    ep_rew_mean      | 1.25     |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 608      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 15350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 730      |
# |    ep_rew_mean      | 1.24     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 608      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 15484    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 735      |
# |    ep_rew_mean      | 1.27     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 609      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 15714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 733      |
# |    ep_rew_mean      | 1.25     |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 609      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 15836    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 732      |
# |    ep_rew_mean      | 1.25     |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 609      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 15926    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 732      |
# |    ep_rew_mean      | 1.25     |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 609      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 16093    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 733      |
# |    ep_rew_mean      | 1.26     |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 609      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 16183    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 731      |
# |    ep_rew_mean      | 1.24     |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 609      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 16273    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 729      |
# |    ep_rew_mean      | 1.23     |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 608      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 16361    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 727      |
# |    ep_rew_mean      | 1.22     |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 500      |
# ...
# |    time_elapsed     | 3408     |
# |    total_timesteps  | 969911   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 229977   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.82e+03 |
# |    ep_rew_mean      | 57.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7988     |
# |    fps              | 284      |
# |    time_elapsed     | 3412     |
# |    total_timesteps  | 971032   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0544   |
# |    n_updates        | 230257   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.82e+03 |
# |    ep_rew_mean      | 57       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7992     |
# |    fps              | 284      |
# |    time_elapsed     | 3416     |
# |    total_timesteps  | 972239   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 230559   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.83e+03 |
# |    ep_rew_mean      | 57.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7996     |
# |    fps              | 284      |
# |    time_elapsed     | 3418     |
# |    total_timesteps  | 972698   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0599   |
# |    n_updates        | 230674   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.82e+03 |
# |    ep_rew_mean      | 56.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8000     |
# |    fps              | 284      |
# |    time_elapsed     | 3420     |
# |    total_timesteps  | 973367   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 230841   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.82e+03 |
# |    ep_rew_mean      | 56.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8004     |
# |    fps              | 284      |
# |    time_elapsed     | 3424     |
# |    total_timesteps  | 974542   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0497   |
# |    n_updates        | 231135   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.83e+03 |
# |    ep_rew_mean      | 57       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8008     |
# |    fps              | 284      |
# |    time_elapsed     | 3429     |
# |    total_timesteps  | 975877   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 231469   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.85e+03 |
# |    ep_rew_mean      | 57.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8012     |
# |    fps              | 284      |
# |    time_elapsed     | 3431     |
# |    total_timesteps  | 976305   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0074   |
# |    n_updates        | 231576   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.85e+03 |
# |    ep_rew_mean      | 57.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8016     |
# |    fps              | 284      |
# |    time_elapsed     | 3434     |
# |    total_timesteps  | 977194   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0592   |
# |    n_updates        | 231798   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.84e+03 |
# |    ep_rew_mean      | 57       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8020     |
# |    fps              | 284      |
# |    time_elapsed     | 3436     |
# |    total_timesteps  | 977693   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 231923   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.84e+03 |
# |    ep_rew_mean      | 57       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8024     |
# |    fps              | 284      |
# |    time_elapsed     | 3439     |
# |    total_timesteps  | 978671   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 232167   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.84e+03 |
# |    ep_rew_mean      | 57.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8028     |
# |    fps              | 284      |
# |    time_elapsed     | 3444     |
# |    total_timesteps  | 979912   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00618  |
# |    n_updates        | 232477   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.84e+03 |
# |    ep_rew_mean      | 57.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8032     |
# |    fps              | 284      |
# |    time_elapsed     | 3447     |
# |    total_timesteps  | 980799   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00456  |
# |    n_updates        | 232699   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.82e+03 |
# |    ep_rew_mean      | 57.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8036     |
# |    fps              | 284      |
# |    time_elapsed     | 3449     |
# |    total_timesteps  | 981431   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00452  |
# |    n_updates        | 232857   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.82e+03 |
# |    ep_rew_mean      | 57.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8040     |
# |    fps              | 284      |
# |    time_elapsed     | 3453     |
# |    total_timesteps  | 982357   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00569  |
# |    n_updates        | 233089   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.82e+03 |
# |    ep_rew_mean      | 57.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8044     |
# |    fps              | 284      |
# |    time_elapsed     | 3457     |
# |    total_timesteps  | 983661   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00935  |
# |    n_updates        | 233415   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.85e+03 |
# |    ep_rew_mean      | 57.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8048     |
# |    fps              | 284      |
# |    time_elapsed     | 3462     |
# |    total_timesteps  | 984954   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 233738   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.86e+03 |
# |    ep_rew_mean      | 57.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8052     |
# |    fps              | 284      |
# |    time_elapsed     | 3464     |
# |    total_timesteps  | 985573   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 233893   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.87e+03 |
# |    ep_rew_mean      | 58       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8056     |
# |    fps              | 284      |
# |    time_elapsed     | 3469     |
# |    total_timesteps  | 986911   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.018    |
# |    n_updates        | 234227   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.86e+03 |
# |    ep_rew_mean      | 57.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8060     |
# |    fps              | 284      |
# |    time_elapsed     | 3472     |
# |    total_timesteps  | 987609   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 234402   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.86e+03 |
# |    ep_rew_mean      | 57.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8064     |
# |    fps              | 284      |
# |    time_elapsed     | 3476     |
# |    total_timesteps  | 988945   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00551  |
# |    n_updates        | 234736   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.88e+03 |
# |    ep_rew_mean      | 58       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8068     |
# |    fps              | 284      |
# |    time_elapsed     | 3481     |
# |    total_timesteps  | 990253   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0059   |
# |    n_updates        | 235063   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.89e+03 |
# |    ep_rew_mean      | 58.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8072     |
# |    fps              | 284      |
# |    time_elapsed     | 3485     |
# |    total_timesteps  | 991399   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00404  |
# |    n_updates        | 235349   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.9e+03  |
# |    ep_rew_mean      | 58.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8076     |
# |    fps              | 284      |
# |    time_elapsed     | 3490     |
# |    total_timesteps  | 992800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00608  |
# |    n_updates        | 235699   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.92e+03 |
# |    ep_rew_mean      | 59       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8080     |
# |    fps              | 284      |
# |    time_elapsed     | 3493     |
# |    total_timesteps  | 993591   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00419  |
# |    n_updates        | 235897   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.92e+03 |
# |    ep_rew_mean      | 59       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8084     |
# |    fps              | 284      |
# |    time_elapsed     | 3498     |
# |    total_timesteps  | 994945   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00849  |
# |    n_updates        | 236236   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.94e+03 |
# |    ep_rew_mean      | 59.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8088     |
# |    fps              | 284      |
# |    time_elapsed     | 3502     |
# |    total_timesteps  | 996116   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00477  |
# |    n_updates        | 236528   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.95e+03 |
# |    ep_rew_mean      | 59.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8092     |
# |    fps              | 284      |
# |    time_elapsed     | 3504     |
# |    total_timesteps  | 996633   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00405  |
# |    n_updates        | 236658   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.95e+03 |
# |    ep_rew_mean      | 59.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8096     |
# |    fps              | 284      |
# |    time_elapsed     | 3510     |
# |    total_timesteps  | 998279   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 237069   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.94e+03 |
# |    ep_rew_mean      | 59.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8100     |
# |    fps              | 284      |
# |    time_elapsed     | 3511     |
# |    total_timesteps  | 998674   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00464  |
# |    n_updates        | 237168   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.94e+03 |
# |    ep_rew_mean      | 59.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8104     |
# |    fps              | 284      |
# |    time_elapsed     | 3516     |
# |    total_timesteps  | 999992   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.005    |
# |    n_updates        | 237497   |
# ----------------------------------

# %%
import os
print(os.listdir('.'))
# Out:
# ['checkpoints', '.virtual_documents', 'dqn_logs', 'dqn_breakout_model.zip']
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from IPython.display import FileLink
FileLink("dqn_breakout_model.zip")
# Out:
# /kaggle/working/dqn_breakout_model.zip
